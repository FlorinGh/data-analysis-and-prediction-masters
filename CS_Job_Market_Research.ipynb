# %% [markdown]
# ## What you need to know
#
# This is a collection of most asked for skills in job openings in computer science.
# The targeted positions are:
# - Data Analyst
# - Data Scientist
# - Machine Learning Engineer
# - Computer Vision Reasearch Engineer
# - Software Engineer Machine Learning
# - Artificial Inteligence Engineer
# - Deep Learning Engineer
# - Data Engineer
#
# The field of machine learning and data analysis is at the cutting edge of technology and it's here to stay; jobs are really abundant and they are usually located in big cities in US and Europe. The following list show what is requested to know for these jobs.
# This list is afterwards plotted on a importance / difficulty matrix and can be used to schedule a training program to acquire these skills.
#
# In this matrix, always start with the *Quick Wins Skills* and plan ahead for *Strategic Skills*. The first quadrant will give your skills a rapid boost and will put you in the race with all the others; the second qudrant will give you shape and personality and will differenciate you from the average.

# %%
import matplotlib.image as mpimg
import matplotlib.pylab as plt
image = mpimg.imread('importDiffMatrix.png')
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Computing skills

# %% [markdown]
# ### Soft skills

# %% [markdown]
# ### Experience

# %% [markdown]
# ### Education
